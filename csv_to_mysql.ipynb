# %%
import pandas as pd

# %%
divvy_q1q2_2014 = pd.read_csv("Divvy_Trips_2014_Q1Q2.csv")
divvy_q1q2_2014.head()
# Out:
#    trip_id        starttime         stoptime  bikeid  tripduration  \
# 0  2355134  6/30/2014 23:57    7/1/2014 0:07    2006           604
# 1  2355133  6/30/2014 23:56    7/1/2014 0:00    2217           263
# 2  2355130  6/30/2014 23:33  6/30/2014 23:35    2798           126
# 3  2355129  6/30/2014 23:26    7/1/2014 0:24     173          3481
# 4  2355128  6/30/2014 23:16  6/30/2014 23:26     173           638
#
#    from_station_id            from_station_name  to_station_id  \
# 0              131    Lincoln Ave & Belmont Ave            303
# 1              282      Halsted St & Maxwell St             22
# 2              327  Sheffield Ave & Webster Ave            225
# 3              134     Peoria St & Jackson Blvd            194
# 4              320     Loomis St & Lexington St            134
#
#             to_station_name    usertype  gender  birthyear
# 0   Broadway & Cornelia Ave  Subscriber    Male     1988.0
# 1        May St & Taylor St  Subscriber    Male     1992.0
# ...

# %%
divvy_q307_2014 = pd.read_csv("Divvy_Trips_2014-Q3-07.csv")
divvy_q30809_2014 = pd.read_csv("Divvy_Trips_2014-Q3-0809.csv")
divvy_q4_2014 = pd.read_csv("Divvy_Trips_2014-Q4.csv")

divvy_q307_2014.head()
# Out:
#    trip_id        starttime       stoptime  bikeid  tripduration  \
# 0  2886259  7/31/2014 23:56  8/1/2014 0:03    2602           386
# 1  2886258  7/31/2014 23:58  8/1/2014 0:07    2403           495
# 2  2886257  7/31/2014 23:58  8/1/2014 2:10     669          7947
# 3  2886256  7/31/2014 23:58  8/1/2014 0:19    2431          1282
# 4  2886255  7/31/2014 23:57  8/1/2014 2:10    2885          7972
#
#    from_station_id             from_station_name  to_station_id  \
# 0              291      Wells St & Evergreen Ave             53
# 1               98    LaSalle St & Washington St            106
# 2              240  Sheridan Rd & Irving Park Rd            240
# 3               47          State St & Kinzie St             14
# 4              240  Sheridan Rd & Irving Park Rd            240
#
#                 to_station_name    usertype  gender  birthyear
# 0            Wells St & Erie St  Subscriber  Female     1979.0
# ...

# %%
divvy_2014 = pd.concat([divvy_q1q2_2014, divvy_q307_2014, divvy_q30809_2014, divvy_q4_2014], ignore_index = True)
divvy_2014.tail()
# Out:
#          trip_id       starttime        stoptime  bikeid  tripduration  \
# 2454629  3810756  10/1/2014 0:01  10/1/2014 0:16    1122           853
# 2454630  3810754  10/1/2014 0:02  10/1/2014 0:10    1531           468
# 2454631  3810753  10/1/2014 0:02  10/1/2014 0:16    2707           836
# 2454632  3810752  10/1/2014 0:01  10/1/2014 0:05    2059           238
# 2454633  3810751  10/1/2014 0:00  10/1/2014 0:09    1316           538
#
#          from_station_id           from_station_name  to_station_id  \
# 2454629              253  Clifton Ave & Lawrence Ave            114
# 2454630              113   Bissell St & Armitage Ave            340
# 2454631              332  Halsted St & Diversey Pkwy            333
# 2454632               92     Carpenter St & Huron St             29
# 2454633               52      Michigan Ave & Lake St            255
#
#                     to_station_name    usertype gender  birthyear
# ...

# %%
divvy_2014.to_csv("divvy_2014.csv")
